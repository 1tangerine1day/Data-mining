# %% [markdown]
# # parameter

# %%
training_data_path = "./training.txt"
test_data_path = "./test.txt"

# %% [markdown]
# # import

# %%
from collections import defaultdict

# %% [markdown]
# # function

# %%
def parserTrainingData(path):
    with open(path) as f:
        lineData = [line.replace('\n','').replace('{','').replace('}','').split(',') for line in f.readlines()]
    
    data01 = []
    for i in lineData:
        temp = []
        for j in i:
            temp += j.split(' ')
        data01 += [temp]
    
    
    data02 = []
    x = []
    y = []
    for i in data01:
        dic = {'0':'S', '1':'0', '3':'X', '4':'X', '2':'Basic'}
        for j in range(0,len(i),2):
            dic[str(i[j])] = i[j+1]
        
        temp=[]
        
        for m in dic:
            temp.append(dic[m])
        data02 += [temp]
        x += [m for m in temp[:-1]]
        y += [temp[-1]]
        print(temp)
    
    return data02

# %%
def parserTestData(path):
    with open(path) as f:
        lineData = [line.replace('\n','').replace('{','').replace('}','').split(',') for line in f.readlines()]
    with open(path) as f:
        z = [line.replace('\n','') for line in f.readlines()]
    
    data01 = []
    for i in lineData:
        temp = []
        for j in i:
            temp += j.split(' ')
        data01 += [temp]
    
    
    data02 = []
    x = []
    y = []
    for i in data01:
        dic = {'0':'S', '1':'0', '3':'X', '4':'X', '2':'Basic'}
        for j in range(0,len(i),2):
            dic[str(i[j])] = i[j+1]
        
        temp=[]
        
        for m in dic:
            temp.append(dic[m])
        data02 += [temp]
        x += [[m for m in temp[:-1]]]
        y += [temp[-1]]
    return x,y,z

# %%
class DecisionTree:
    def __init__(self, col=-1, value=None, trueBranch=None, falseBranch=None, results=None, summary=None):
        self.col = col
        self.value = value
        self.trueBranch = trueBranch
        self.falseBranch = falseBranch
        self.results = results # None for nodes, not None for leaves
        self.summary = summary

# %%
def divideSet(rows, column, value):
    splittingFunction = None
    if isinstance(value, int) or isinstance(value, float): # for int and float values
        splittingFunction = lambda row : row[column] >= value
    else: # for strings
        splittingFunction = lambda row : row[column] == value
    list1 = [row for row in rows if splittingFunction(row)]
    list2 = [row for row in rows if not splittingFunction(row)]
    return (list1, list2)

# %%
def uniqueCounts(rows):
    results = {}
    for row in rows:
        #response variable is in the last column
        r = row[-1]
        if r not in results: results[r] = 0
        results[r] += 1
    return results

# %%
def entropy(rows):
    from math import log
    log2 = lambda x: log(x)/log(2)
    results = uniqueCounts(rows)

    entr = 0.0
    for r in results:
        p = float(results[r])/len(rows)
        entr -= p*log2(p)
    return entr

# %%
def gini(rows):
    total = len(rows)
    counts = uniqueCounts(rows)
    imp = 0.0

    for k1 in counts:
        p1 = float(counts[k1])/total
        for k2 in counts:
            if k1 == k2: continue
            p2 = float(counts[k2])/total
            imp += p1*p2
    return imp

# %%
def variance(rows):
    if len(rows) == 0: return 0
    data = [float(row[len(row) - 1]) for row in rows]
    mean = sum(data) / len(data)

    variance = sum([(d-mean)**2 for d in data]) / len(data)
    return variance

# %%
def growDecisionTreeFrom(rows, evaluationFunction=entropy):
    """Grows and then returns a binary decision tree.
    evaluationFunction: entropy or gini"""

    if len(rows) == 0: return DecisionTree()
    currentScore = evaluationFunction(rows)

    bestGain = 0.0
    bestAttribute = None
    bestSets = None

    columnCount = len(rows[0]) - 1
    for col in range(0, columnCount):
        columnValues = [row[col] for row in rows]

        
        lsUnique = list(set(columnValues))

        for value in lsUnique:
            (set1, set2) = divideSet(rows, col, value)

            p = float(len(set1)) / len(rows)
            gain = currentScore - p*evaluationFunction(set1) - (1-p)*evaluationFunction(set2)
            if gain>bestGain and len(set1)>0 and len(set2)>0:
                bestGain = gain
                bestAttribute = (col, value)
                bestSets = (set1, set2)

    dcY = {'impurity' : '%.3f' % currentScore, 'samples' : '%d' % len(rows)}
    if bestGain > 0:
        trueBranch = growDecisionTreeFrom(bestSets[0], evaluationFunction)
        falseBranch = growDecisionTreeFrom(bestSets[1], evaluationFunction)
        return DecisionTree(col=bestAttribute[0], value=bestAttribute[1], trueBranch=trueBranch,
                            falseBranch=falseBranch, summary=dcY)
    else:
        return DecisionTree(results=uniqueCounts(rows), summary=dcY)

# %%
def classify(observations, tree, dataMissing=False):
    """Classifies the observationss according to the tree.
    dataMissing: true or false if data are missing or not. """

    def classifyWithoutMissingData(observations, tree):
        if tree.results != None:  # leaf
            return tree.results
        else:
            v = observations[tree.col]
            branch = None
            if isinstance(v, int) or isinstance(v, float):
                if v >= tree.value: branch = tree.trueBranch
                else: branch = tree.falseBranch
            else:
                if v == tree.value: branch = tree.trueBranch
                else: branch = tree.falseBranch
        return classifyWithoutMissingData(observations, branch)


    def classifyWithMissingData(observations, tree):
        if tree.results != None:  # leaf
            return tree.results
        else:
            v = observations[tree.col]
            if v == None:
                tr = classifyWithMissingData(observations, tree.trueBranch)
                fr = classifyWithMissingData(observations, tree.falseBranch)
                tcount = sum(tr.values())
                fcount = sum(fr.values())
                tw = float(tcount)/(tcount + fcount)
                fw = float(fcount)/(tcount + fcount)
                result = defaultdict(int)
                for k, v in tr.items(): result[k] += v*tw
                for k, v in fr.items(): result[k] += v*fw
                return dict(result)
            else:
                branch = None
                if isinstance(v, int) or isinstance(v, float):
                    if v >= tree.value: branch = tree.trueBranch
                    else: branch = tree.falseBranch
                else:
                    if v == tree.value: branch = tree.trueBranch
                    else: branch = tree.falseBranch
            return classifyWithMissingData(observations, branch)

    # function body
    if dataMissing:
        return classifyWithMissingData(observations, tree)
    else:
        return classifyWithoutMissingData(observations, tree)

# %% [markdown]
# # main function

# %%
dcHeadings = {}
trainingData = parserTrainingData(training_data_path)
decisionTree = growDecisionTreeFrom(trainingData)
# Out:
# ['S', '1', '39', '100000', 'Basic']
# ['M', '0', '85', '80000', 'Gold']
# ['M', '1', '90', '20000', 'Gold']
# ['S', '0', '31', '20000', 'Normal']
# ['M', '0', '49', '40000', 'Basic']
# ['M', '2', '58', '40000', 'Silver']
# ['M', '1', '51', '60000', 'Basic']
# ['S', '0', '78', '40000', 'Basic']
# ['M', '2', '21', '80000', 'Basic']
# ['M', '3', '51', '100000', 'Gold']
# ['S', '1', '33', '120000', 'Basic']
# ['S', '0', '29', '80000', 'Normal']
# ['S', '1', '25', '60000', 'Basic']
# ['M', '1', '88', '60000', 'Basic']
# ['M', '1', '59', '20000', 'Normal']
# ['S', '1', '81', '60000', 'Basic']
# ['S', '3', '72', '40000', 'Normal']
# ['S', '1', '86', '40000', 'Basic']
# ['S', '1', '47', '80000', 'Normal']
# ['M', '1', '26', '40000', 'Basic']
# ['M', '1', '82', '40000', 'Silver']
# ['M', '2', '53', '40000', 'Silver']
# ['S', '2', '84', '60000', 'Silver']
# ['S', '0', '79', '20000', 'Normal']
# ['S', '0', '48', '100000', 'Basic']
# ['S', '0', '46', '40000', 'Silver']
# ['M', '0', '66', '60000', 'Basic']
# ['M', '0', '30', '40000', 'Gold']
# ['M', '2', '63', '120000', 'Basic']
# ['M', '1', '83', '40000', 'Basic']
# ['S', '2', '22', '60000', 'Basic']
# ['M', '0', '70', '80000', 'Basic']
# ['S', '1', '29', '60000', 'Basic']
# ['M', '2', '81', '80000', 'Basic']
# ['S', '3', '80', '60000', 'Gold']
# ['S', '1', '85', '60000', 'Basic']
# ['S', '0', '39', '60000', 'Basic']
# ['M', '0', '42', '40000', 'Basic']
# ['S', '3', '41', '60000', 'Basic']
# ['M', '0', '74', '120000', 'Normal']
# ['S', '1', '81', '80000', 'Basic']
# ['M', '1', '35', '40000', 'Basic']
# ['S', '1', '23', '40000', 'Basic']
# ['S', '1', '83', '80000', 'Basic']
# ['M', '4', '84', '100000', 'Basic']
# ['S', '0', '72', '160000', 'Silver']
# ['M', '0', '49', '40000', 'Basic']
# ['M', '0', '73', '60000', 'Silver']
# ['S', '1', '70', '140000', 'Basic']
# ['S', '3', '78', '80000', 'Gold']
# ['M', '4', '45', '40000', 'Gold']
# ['M', '2', '88', '40000', 'Basic']
# ['M', '3', '68', '80000', 'Gold']
# ['S', '0', '39', '40000', 'Silver']
# ['S', '1', '76', '20000', 'Normal']
# ['M', '2', '65', '120000', 'Basic']
# ['M', '2', '40', '60000', 'Normal']
# ['M', '2', '44', '60000', 'Basic']
# ['M', '4', '58', '40000', 'Gold']
# ['S', '2', '86', '60000', 'Basic']
# ['M', '1', '55', '60000', 'Basic']
# ['M', '0', '69', '140000', 'Silver']
# ['S', '0', '84', '40000', 'Normal']
# ['M', '1', '68', '40000', 'Silver']
# ['S', '0', '21', '60000', 'Basic']
# ['S', '3', '67', '40000', 'Gold']
# ['S', '1', '72', '120000', 'Basic']
# ['M', '0', '83', '40000', 'Basic']
# ['S', '1', '31', '60000', 'Basic']
# ['S', '0', '28', '40000', 'Basic']
# ['S', '5', '33', '40000', 'Gold']
# ['M', '3', '60', '80000', 'Gold']
# ['M', '2', '75', '40000', 'Gold']
# ['S', '3', '35', '40000', 'Gold']
# ['M', '1', '87', '60000', 'Basic']
# ['S', '0', '83', '60000', 'Silver']
# ['S', '1', '79', '40000', 'Basic']
# ['S', '0', '60', '140000', 'Basic']
# ['S', '1', '43', '60000', 'Basic']
# ['M', '1', '54', '60000', 'Basic']
# ['S', '1', '56', '40000', 'Basic']
# ['M', '4', '59', '120000', 'Gold']
# ['S', '2', '31', '60000', 'Basic']
# ['M', '1', '68', '60000', 'Silver']
# ['M', '2', '54', '40000', 'Normal']
# ['S', '1', '89', '40000', 'Basic']
# ['M', '2', '51', '120000', 'Basic']
# ['M', '1', '57', '140000', 'Gold']
# ['S', '3', '26', '40000', 'Gold']
# ['M', '1', '24', '40000', 'Basic']
# ['S', '0', '44', '100000', 'Normal']
# ['M', '4', '66', '140000', 'Basic']
# ['S', '2', '30', '80000', 'Gold']
# ['S', '1', '61', '20000', 'Normal']
# ['M', '2', '70', '120000', 'Basic']
# ['S', '0', '49', '140000', 'Silver']
# ['S', '0', '77', '60000', 'Basic']
# ['S', '0', '48', '60000', 'Basic']
# ['M', '3', '66', '60000', 'Gold']
# ['S', '1', '71', '80000', 'Basic']
# ['S', '0', '25', '40000', 'Silver']
# ['M', '0', '28', '40000', 'Basic']
# ['S', '3', '86', '40000', 'Gold']
# ['S', '1', '48', '40000', 'Basic']
# ['M', '1', '67', '80000', 'Basic']
# ['M', '5', '21', '40000', 'Gold']
# ['M', '0', '79', '40000', 'Basic']
# ['M', '1', '69', '20000', 'Basic']
# ['S', '1', '71', '80000', 'Silver']
# ['M', '1', '58', '80000', 'Basic']
# ['M', '0', '35', '100000', 'Basic']
# ['M', '3', '52', '160000', 'Gold']
# ['S', '1', '36', '40000', 'Basic']
# ['S', '0', '57', '40000', 'Basic']
# ['S', '1', '23', '20000', 'Normal']
# ['S', '1', '66', '80000', 'Gold']
# ['S', '0', '46', '60000', 'Basic']
# ['M', '0', '87', '40000', 'Basic']
# ['M', '4', '43', '40000', 'Gold']
# ['S', '0', '43', '160000', 'Silver']
# ['S', '1', '88', '40000', 'Basic']
# ['S', '1', '80', '140000', 'Basic']
# ['M', '1', '36', '140000', 'Basic']
# ['M', '1', '70', '40000', 'Silver']
# ['M', '0', '28', '20000', 'Normal']
# ['S', '2', '53', '40000', 'Basic']
# ['M', '1', '68', '60000', 'Silver']
# ['S', '1', '53', '100000', 'Basic']
# ['S', '0', '75', '60000', 'Basic']
# ['M', '0', '51', '20000', 'Normal']
# ['S', '1', '56', '40000', 'Silver']
# ['S', '0', '67', '40000', 'Gold']
# ['S', '1', '85', '60000', 'Basic']
# ['S', '1', '82', '80000', 'Basic']
# ['S', '1', '76', '100000', 'Basic']
# ['M', '3', '44', '140000', 'Silver']
# ['S', '3', '57', '40000', 'Silver']
# ['M', '2', '75', '40000', 'Basic']
# ['S', '1', '69', '40000', 'Basic']
# ['M', '0', '53', '40000', 'Basic']
# ['M', '1', '61', '60000', 'Gold']
# ['M', '1', '42', '60000', 'Basic']
# ['M', '1', '25', '20000', 'Normal']
# ['S', '2', '36', '140000', 'Silver']
# ['S', '3', '26', '140000', 'Gold']
# ['M', '1', '40', '140000', 'Basic']
# ['M', '4', '83', '60000', 'Silver']
# ['S', '1', '50', '40000', 'Basic']
# ['M', '1', '36', '40000', 'Basic']
# ['M', '2', '71', '40000', 'Basic']
# ['S', '2', '41', '40000', 'Normal']
# ['M', '1', '47', '120000', 'Normal']
# ['S', '3', '86', '80000', 'Gold']
# ['M', '0', '84', '80000', 'Basic']
# ['M', '0', '34', '80000', 'Basic']
# ['S', '1', '56', '120000', 'Silver']
# ['M', '2', '90', '20000', 'Normal']
# ['M', '0', '39', '40000', 'Basic']
# ['S', '3', '60', '60000', 'Gold']
# ['M', '0', '39', '40000', 'Basic']
# ['M', '1', '67', '80000', 'Basic']
# ['M', '2', '37', '20000', 'Normal']
# ['S', '4', '48', '60000', 'Gold']
# ['S', '2', '53', '40000', 'Basic']
# ['S', '0', '65', '80000', 'Basic']
# ['S', '2', '68', '80000', 'Basic']
# ['M', '0', '68', '40000', 'Basic']
# ['M', '1', '37', '80000', 'Basic']
# ['S', '0', '44', '20000', 'Normal']
# ['S', '1', '80', '40000', 'Normal']
# ['S', '2', '68', '140000', 'Basic']
# ['S', '0', '58', '40000', 'Gold']
# ['S', '3', '60', '40000', 'Gold']
# ['S', '1', '47', '40000', 'Basic']
# ['S', '0', '24', '40000', 'Normal']
# ['S', '0', '40', '120000', 'Basic']
# ['M', '0', '25', '80000', 'Silver']
# ['M', '0', '33', '80000', 'Basic']
# ['S', '1', '82', '60000', 'Normal']
# ['M', '3', '55', '80000', 'Basic']
# ['M', '0', '35', '120000', 'Gold']
# ['S', '1', '76', '140000', 'Basic']
# ['S', '1', '31', '60000', 'Basic']
# ['S', '3', '32', '40000', 'Silver']
# ['S', '1', '77', '40000', 'Basic']
# ['S', '1', '69', '100000', 'Basic']
# ['M', '0', '25', '40000', 'Silver']
# ['M', '1', '41', '60000', 'Basic']
# ['M', '1', '81', '80000', 'Basic']
# ['S', '0', '36', '20000', 'Normal']
# ['S', '0', '51', '80000', 'Gold']
# ['S', '0', '23', '60000', 'Basic']
# ['S', '0', '58', '60000', 'Basic']
# ['S', '1', '30', '20000', 'Normal']
# ['S', '1', '35', '80000', 'Basic']
# ['M', '1', '34', '80000', 'Gold']
# ['M', '0', '52', '40000', 'Basic']
# ['M', '1', '61', '20000', 'Normal']
# ['S', '0', '54', '100000', 'Silver']
# ['M', '3', '23', '80000', 'Gold']
# ['S', '0', '24', '20000', 'Normal']
# ['M', '2', '54', '160000', 'Normal']
# ['S', '1', '48', '40000', 'Basic']
# ['M', '2', '32', '60000', 'Normal']
# ['M', '0', '40', '100000', 'Silver']
# ['M', '0', '21', '80000', 'Basic']
# ['M', '1', '62', '80000', 'Normal']
# ['M', '2', '84', '120000', 'Basic']
# ['S', '0', '75', '40000', 'Gold']
# ['M', '0', '89', '140000', 'Normal']
# ['S', '2', '41', '20000', 'Normal']
# ['M', '0', '28', '120000', 'Basic']
# ['S', '0', '75', '40000', 'Gold']
# ['M', '1', '40', '60000', 'Basic']
# ['M', '3', '25', '80000', 'Gold']
# ['S', '2', '33', '120000', 'Basic']
# ['M', '3', '81', '40000', 'Gold']
# ['S', '1', '55', '40000', 'Gold']
# ['M', '1', '34', '140000', 'Silver']
# ['M', '0', '76', '120000', 'Basic']
# ['M', '2', '31', '60000', 'Gold']
# ['S', '1', '31', '100000', 'Gold']
# ['M', '2', '76', '20000', 'Normal']
# ['S', '2', '68', '120000', 'Basic']
# ['S', '2', '25', '40000', 'Gold']
# ['S', '2', '40', '100000', 'Basic']
# ['S', '3', '80', '60000', 'Basic']
# ['S', '0', '35', '40000', 'Basic']
# ['S', '1', '50', '60000', 'Basic']
# ['M', '1', '23', '40000', 'Gold']
# ['S', '1', '69', '100000', 'Gold']
# ['S', '3', '45', '20000', 'Normal']
# ['M', '0', '50', '20000', 'Normal']
# ['M', '2', '49', '40000', 'Basic']
# ['S', '1', '67', '40000', 'Basic']
# ['M', '3', '76', '60000', 'Gold']
# ['S', '5', '69', '100000', 'Gold']
# ['S', '1', '38', '40000', 'Basic']
# ['S', '2', '39', '80000', 'Basic']
# ['M', '0', '69', '40000', 'Basic']
# ['M', '3', '63', '60000', 'Gold']
# ['M', '0', '47', '40000', 'Basic']
# ['S', '1', '55', '80000', 'Silver']
# ['S', '1', '36', '100000', 'Basic']
# ['M', '2', '77', '60000', 'Basic']
# ['S', '1', '30', '80000', 'Silver']
# ['M', '1', '20', '40000', 'Silver']
# ['M', '3', '34', '60000', 'Basic']
# ['S', '2', '77', '40000', 'Basic']
# ['S', '1', '44', '60000', 'Basic']
# ['M', '0', '30', '80000', 'Basic']
# ['S', '1', '65', '40000', 'Basic']
# ['M', '1', '26', '40000', 'Basic']
# ['S', '1', '21', '100000', 'Basic']
# ['M', '3', '72', '40000', 'Gold']
# ['M', '1', '58', '40000', 'Basic']
# ['M', '1', '20', '40000', 'Basic']
# ['S', '0', '42', '60000', 'Silver']
# ['M', '1', '76', '140000', 'Silver']
# ['S', '1', '25', '140000', 'Basic']
# ['M', '0', '34', '20000', 'Normal']
# ['M', '3', '25', '60000', 'Gold']
# ['S', '2', '41', '40000', 'Basic']
# ['M', '2', '23', '60000', 'Basic']
# ['S', '0', '40', '60000', 'Basic']
# ['S', '1', '45', '40000', 'Silver']
# ['S', '1', '57', '40000', 'Basic']
# ['S', '1', '60', '80000', 'Silver']
# ['M', '0', '59', '40000', 'Basic']
# ['M', '0', '22', '40000', 'Silver']
# ['S', '1', '29', '80000', 'Basic']
# ['S', '1', '65', '60000', 'Silver']
# ['M', '2', '53', '40000', 'Basic']
# ['S', '1', '43', '80000', 'Gold']
# ['M', '2', '33', '120000', 'Basic']
# ['S', '2', '90', '100000', 'Basic']
# ['M', '0', '67', '20000', 'Normal']
# ['S', '0', '84', '40000', 'Basic']
# ['M', '0', '80', '40000', 'Basic']
# ['S', '3', '88', '20000', 'Normal']
# ['S', '0', '55', '80000', 'Basic']
# ['M', '2', '28', '40000', 'Basic']
# ['M', '1', '20', '80000', 'Gold']
# ['M', '0', '49', '60000', 'Basic']
# ['M', '4', '86', '60000', 'Basic']
# ['M', '1', '87', '20000', 'Normal']
# ['S', '2', '62', '20000', 'Normal']
# ['M', '0', '54', '80000', 'Basic']
# ['M', '0', '68', '40000', 'Silver']
# ['M', '3', '26', '40000', 'Gold']
# ['S', '0', '74', '20000', 'Normal']
# ['M', '3', '87', '60000', 'Gold']
# ['M', '2', '32', '60000', 'Basic']
# ['M', '5', '86', '160000', 'Gold']
# ['M', '1', '59', '60000', 'Basic']
# ['M', '1', '78', '40000', 'Basic']
# ['S', '0', '87', '120000', 'Gold']
# ['S', '0', '78', '20000', 'Normal']
# ['S', '0', '25', '40000', 'Basic']
# ['M', '1', '77', '40000', 'Basic']
# ['S', '2', '87', '40000', 'Silver']
# ['S', '1', '23', '40000', 'Basic']
# ['S', '0', '34', '60000', 'Basic']
# ['S', '1', '38', '100000', 'Gold']
# ['M', '0', '37', '40000', 'Normal']
# ['M', '0', '69', '80000', 'Basic']
# ['S', '1', '76', '60000', 'Gold']
# ['S', '1', '42', '80000', 'Basic']
# ['M', '1', '31', '120000', 'Basic']
# ['M', '1', '20', '120000', 'Basic']
# ['M', '2', '80', '40000', 'Gold']
# ['S', '2', '67', '40000', 'Basic']
# ['M', '1', '44', '120000', 'Basic']
# ['S', '0', '61', '20000', 'Normal']
# ['S', '0', '58', '40000', 'Basic']
# ['M', '1', '66', '60000', 'Basic']
# ['S', '3', '32', '60000', 'Gold']
# ['S', '2', '76', '80000', 'Basic']
# ['M', '1', '67', '20000', 'Normal']
# ['M', '0', '27', '160000', 'Gold']
# ['M', '3', '64', '60000', 'Gold']
# ['M', '0', '64', '120000', 'Normal']
# ['S', '0', '39', '40000', 'Basic']
# ['M', '2', '39', '40000', 'Basic']
# ['S', '2', '54', '120000', 'Basic']
# ['S', '0', '81', '80000', 'Basic']
# ['M', '1', '51', '60000', 'Basic']
# ['S', '3', '64', '140000', 'Silver']
# ['S', '1', '79', '140000', 'Basic']
# ['S', '1', '64', '40000', 'Basic']
# ['M', '1', '87', '40000', 'Basic']
# ['M', '1', '63', '40000', 'Basic']
# ['M', '1', '67', '60000', 'Basic']
# ['S', '0', '79', '40000', 'Basic']
# ['S', '2', '26', '100000', 'Basic']
# ['M', '1', '35', '60000', 'Normal']
# ['S', '4', '29', '40000', 'Silver']
# ['S', '1', '55', '60000', 'Basic']
# ['S', '0', '68', '60000', 'Basic']
# ['S', '1', '58', '120000', 'Basic']
# ['S', '0', '41', '40000', 'Silver']
# ['S', '0', '36', '60000', 'Basic']
# ['M', '1', '32', '20000', 'Normal']
# ['S', '0', '25', '100000', 'Basic']
# ['S', '2', '66', '60000', 'Basic']
# ['S', '1', '89', '40000', 'Basic']
# ['S', '1', '80', '20000', 'Normal']
# ['M', '1', '24', '80000', 'Silver']
# ['M', '1', '54', '40000', 'Basic']
# ['M', '1', '34', '100000', 'Basic']
# ['S', '3', '89', '140000', 'Gold']
# ['M', '1', '54', '140000', 'Basic']
# ['S', '1', '86', '80000', 'Basic']
# ['M', '2', '80', '40000', 'Basic']
# ['M', '0', '49', '80000', 'Basic']
# ['M', '1', '47', '120000', 'Gold']
# ['S', '0', '89', '140000', 'Basic']
# ['M', '1', '52', '40000', 'Basic']
# ['S', '1', '86', '80000', 'Basic']
# ['M', '1', '35', '20000', 'Normal']
# ['S', '0', '44', '40000', 'Basic']
# ['S', '0', '23', '60000', 'Silver']
# ['M', '3', '52', '60000', 'Silver']
# ['S', '0', '34', '140000', 'Basic']
# ['M', '2', '32', '20000', 'Normal']
# ['M', '1', '38', '60000', 'Normal']
# ['M', '3', '61', '80000', 'Gold']
# ['M', '0', '64', '160000', 'Gold']
# ['M', '1', '64', '140000', 'Basic']
# ['M', '0', '26', '40000', 'Silver']
# ['S', '1', '33', '40000', 'Normal']
# ['S', '0', '57', '40000', 'Basic']
# ['S', '1', '46', '140000', 'Basic']
# ['M', '0', '35', '40000', 'Basic']
# ['M', '1', '37', '80000', 'Silver']
# ['S', '2', '24', '60000', 'Basic']
# ['S', '5', '71', '100000', 'Gold']
# ['M', '0', '88', '140000', 'Silver']
# ['S', '0', '85', '40000', 'Normal']
# ['M', '2', '23', '60000', 'Basic']
# ['M', '4', '59', '40000', 'Gold']
# ['S', '0', '33', '40000', 'Basic']
# ['S', '1', '82', '40000', 'Silver']
# ['M', '0', '53', '20000', 'Normal']
# ['S', '3', '21', '20000', 'Normal']
# ['M', '1', '79', '80000', 'Gold']
# ['S', '1', '54', '40000', 'Basic']
# ['M', '0', '58', '40000', 'Basic']
# ['M', '1', '73', '160000', 'Gold']
# ['S', '2', '30', '80000', 'Silver']
# ['M', '2', '30', '120000', 'Basic']
# ['M', '2', '43', '20000', 'Normal']
# ['S', '1', '58', '40000', 'Silver']
# ['M', '1', '43', '100000', 'Silver']
# ['M', '4', '66', '40000', 'Gold']
# ['M', '0', '42', '40000', 'Basic']
# ['M', '1', '46', '40000', 'Basic']
# ['S', '1', '58', '40000', 'Basic']
# ['M', '1', '75', '60000', 'Gold']
# ['S', '0', '72', '60000', 'Basic']
# ['S', '0', '78', '20000', 'Normal']
# ['M', '1', '34', '40000', 'Gold']
# ['M', '0', '47', '120000', 'Silver']
# ['S', '1', '77', '60000', 'Basic']
# ['M', '1', '59', '120000', 'Gold']
# ['M', '0', '55', '80000', 'Basic']
# ['S', '0', '51', '100000', 'Gold']
# ['S', '0', '32', '40000', 'Basic']
# ['S', '2', '85', '140000', 'Normal']
# ['S', '2', '26', '40000', 'Silver']
# ['M', '5', '29', '40000', 'Gold']
# ['S', '1', '31', '120000', 'Silver']
# ['M', '1', '73', '60000', 'Basic']
# ['S', '3', '41', '60000', 'Gold']
# ['M', '2', '80', '40000', 'Basic']
# ['M', '1', '45', '60000', 'Basic']
# ['M', '1', '77', '40000', 'Basic']
# ['M', '3', '83', '40000', 'Gold']
# ['M', '1', '52', '80000', 'Gold']
# ['M', '0', '50', '20000', 'Normal']
# ['M', '1', '70', '20000', 'Normal']
# ['M', '1', '22', '140000', 'Basic']
# ['M', '1', '56', '40000', 'Silver']
# ['M', '2', '47', '40000', 'Basic']
# ['S', '0', '56', '100000', 'Basic']
# ['M', '0', '35', '60000', 'Normal']
# ['S', '2', '64', '40000', 'Basic']
# ['S', '1', '34', '20000', 'Normal']
# ['M', '3', '44', '160000', 'Gold']
# ['M', '0', '49', '80000', 'Basic']
# ['M', '0', '73', '40000', 'Basic']
# ['S', '0', '76', '100000', 'Basic']
# ['M', '2', '64', '20000', 'Normal']
# ['M', '3', '26', '40000', 'Gold']
# ['S', '1', '45', '40000', 'Gold']
# ['S', '1', '69', '40000', 'Basic']
# ['S', '1', '57', '40000', 'Basic']
# ['M', '0', '47', '60000', 'Normal']
# ['S', '2', '49', '80000', 'Basic']
# ['S', '2', '90', '80000', 'Normal']
# ['S', '0', '67', '40000', 'Basic']
# ['S', '0', '84', '80000', 'Basic']
# ['S', '3', '69', '60000', 'Gold']
# ['S', '2', '89', '40000', 'Silver']
# ['M', '0', '55', '40000', 'Basic']
# ['S', '0', '28', '40000', 'Silver']
# ['M', '0', '78', '100000', 'Normal']
# ['S', '3', '49', '80000', 'Normal']
# ['M', '0', '75', '40000', 'Basic']
# ['M', '1', '75', '80000', 'Basic']
# ['M', '2', '50', '20000', 'Normal']
# ['S', '3', '42', '60000', 'Gold']
# ['S', '2', '68', '40000', 'Silver']
# ['S', '0', '26', '120000', 'Basic']
# ['S', '2', '54', '140000', 'Basic']
# ['M', '3', '79', '20000', 'Normal']
# ['M', '0', '50', '40000', 'Basic']
# ['S', '1', '35', '20000', 'Normal']
# ['S', '1', '58', '20000', 'Normal']
# ['S', '0', '34', '120000', 'Basic']
# ['S', '4', '38', '80000', 'Gold']
# ['M', '3', '50', '60000', 'Gold']
# ['S', '1', '68', '40000', 'Basic']
# ['M', '3', '65', '40000', 'Gold']
# ['M', '0', '58', '40000', 'Basic']
# ['M', '0', '26', '80000', 'Silver']
# ['M', '0', '39', '140000', 'Basic']
# ['S', '1', '57', '60000', 'Basic']
# ['M', '3', '52', '80000', 'Gold']
# ['M', '0', '35', '40000', 'Gold']
# ['S', '1', '43', '80000', 'Basic']
# ['S', '1', '24', '60000', 'Normal']
# ['S', '3', '25', '40000', 'Gold']
# ['M', '2', '36', '40000', 'Basic']
# ['M', '1', '27', '80000', 'Basic']
# ['M', '0', '41', '40000', 'Basic']
# ['S', '2', '83', '40000', 'Basic']
# ['S', '0', '51', '60000', 'Basic']
# ['M', '2', '37', '80000', 'Normal']
# ['S', '1', '72', '160000', 'Silver']
# ['M', '1', '33', '40000', 'Gold']
# ['S', '1', '39', '120000', 'Basic']
# ['S', '1', '78', '80000', 'Basic']
# ['M', '1', '76', '140000', 'Basic']
# ['S', '0', '27', '40000', 'Basic']
# ['M', '1', '48', '20000', 'Normal']
# ['M', '0', '82', '20000', 'Normal']
# ['S', '5', '31', '20000', 'Normal']
# ['M', '3', '52', '40000', 'Gold']
# ['M', '3', '27', '40000', 'Silver']
# ['S', '2', '56', '120000', 'Silver']

# %%
# print(classify(['S', '2', '56', '120000'], decisionTree, dataMissing=True)) # Silver
# print(classify(['S', '1', '72', '160000'], decisionTree, dataMissing=True)) # Silver
# print(classify(['S', '0', '56', '100000'], decisionTree, dataMissing=True)) # Basic
# print(classify(['S', '1', '39', '120000'], decisionTree, dataMissing=True)) # Basic
# print(classify(['M', '3', '44', '160000'], decisionTree, dataMissing=True)) # Gold
# print(classify(['M', '3', '83', '40000'], decisionTree, dataMissing=True)) # Gold
# print(classify(['M', '1', '78', '20000'], decisionTree, dataMissing=True)) # Normal
# print(classify(['M', '0', '74', '120000'], decisionTree, dataMissing=True)) # Normal

# %% [markdown]
# # test tree model

# %%
question,answer,string = parserTestData(test_data_path)
right_count = 0
output = []
for i in range(len(question)) :
    guess = classify(question[i], decisionTree, dataMissing=True)
    print(string[i])
    print("input" + str(i) + " : " + str(question[i]) )
    print("classify : " + str(guess))
    print("answer   : " + str(answer[i]))
    
    
    
    for key in guess:
        output += [str(string[i]) + "  member_card = " + str(key)]
        if key in (answer[i],):
            right_count += 1
            print("Right !!!")
            break
        else:
            print("Wrong !!!")
            break
    print("-----------------------------------------------------------------------")
# Out:
# {0 M,1 1,3 59,4 60000}
# input0 : ['M', '1', '59', '60000']
# classify : {'Basic': 1}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 3,2 Silver,3 43,4 160000}
# input1 : ['S', '3', '43', '160000']
# classify : {'Gold': 23}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 52,4 120000}
# input2 : ['M', '2', '52', '120000']
# classify : {'Basic': 11}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,2 Normal,3 30,4 60000}
# input3 : ['M', '2', '30', '60000']
# classify : {'Basic': 2}
# answer   : Normal
# Wrong !!!
# -----------------------------------------------------------------------
# {3 73,4 60000}
# input4 : ['S', '0', '73', '60000']
# classify : {'Basic': 14}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,2 Silver,3 53,4 40000}
# input5 : ['S', '1', '53', '40000']
# classify : {'Basic': 55}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,2 Silver,3 24,4 60000}
# input6 : ['M', '0', '24', '60000']
# classify : {'Silver': 4}
# answer   : Silver
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,2 Silver,3 50,4 40000}
# input7 : ['M', '2', '50', '40000']
# classify : {'Basic': 6}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,3 46,4 140000}
# input8 : ['S', '1', '46', '140000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 21,4 40000}
# input9 : ['M', '2', '21', '40000']
# classify : {'Basic': 6}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 2,3 83,4 80000}
# input10 : ['S', '2', '83', '80000']
# classify : {'Basic': 19}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 2,3 39,4 40000}
# input11 : ['S', '2', '39', '40000']
# classify : {'Silver': 1, 'Basic': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 55,4 40000}
# input12 : ['M', '2', '55', '40000']
# classify : {'Basic': 6}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 4,2 Gold,3 25,4 60000}
# input13 : ['S', '4', '25', '60000']
# classify : {'Gold': 2}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {3 50,4 40000}
# input14 : ['S', '0', '50', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,3 65,4 80000}
# input15 : ['S', '1', '65', '80000']
# classify : {'Basic': 7}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 38,4 40000}
# input16 : ['M', '1', '38', '40000']
# classify : {'Normal': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,3 72,4 80000}
# input17 : ['M', '0', '72', '80000']
# classify : {'Basic': 19}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 4,2 Normal,3 48,4 120000}
# input18 : ['M', '4', '48', '120000']
# classify : {'Basic': 3}
# answer   : Normal
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 53,4 40000}
# input19 : ['M', '1', '53', '40000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 2,2 Gold,3 52,4 40000}
# input20 : ['S', '2', '52', '40000']
# classify : {'Basic': 13}
# answer   : Gold
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,2 Normal,3 70,4 20000}
# input21 : ['M', '1', '70', '20000']
# classify : {'Normal': 47}
# answer   : Normal
# Right !!!
# -----------------------------------------------------------------------
# {2 Silver,3 79,4 100000}
# input22 : ['S', '0', '79', '100000']
# classify : {'Basic': 7}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {2 Normal,3 73,4 20000}
# input23 : ['S', '0', '73', '20000']
# classify : {'Normal': 47}
# answer   : Normal
# Right !!!
# -----------------------------------------------------------------------
# {1 1,3 41,4 60000}
# input24 : ['S', '1', '41', '60000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 3,2 Gold,3 42,4 60000}
# input25 : ['S', '3', '42', '60000']
# classify : {'Gold': 4}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 4,3 72,4 20000}
# input26 : ['M', '4', '72', '20000']
# classify : {'Normal': 47}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 3,2 Gold,3 66,4 100000}
# input27 : ['M', '3', '66', '100000']
# classify : {'Gold': 23}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {2 Normal,3 50,4 20000}
# input28 : ['S', '0', '50', '20000']
# classify : {'Normal': 47}
# answer   : Normal
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 4,2 Gold,3 58,4 100000}
# input29 : ['M', '4', '58', '100000']
# classify : {'Basic': 3}
# answer   : Gold
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,3 39,4 80000}
# input30 : ['S', '1', '39', '80000']
# classify : {'Basic': 7}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,2 Normal,3 80,4 20000}
# input31 : ['M', '0', '80', '20000']
# classify : {'Normal': 47}
# answer   : Normal
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 33,4 40000}
# input32 : ['M', '1', '33', '40000']
# classify : {'Gold': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 23,4 40000}
# input33 : ['M', '1', '23', '40000']
# classify : {'Gold': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {2 Gold,3 37,4 60000}
# input34 : ['S', '0', '37', '60000']
# classify : {'Normal': 2}
# answer   : Gold
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 28,4 40000}
# input35 : ['M', '1', '28', '40000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 65,4 60000}
# input36 : ['M', '1', '65', '60000']
# classify : {'Silver': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,2 Normal,3 51,4 40000}
# input37 : ['M', '0', '51', '40000']
# classify : {'Basic': 1}
# answer   : Normal
# Wrong !!!
# -----------------------------------------------------------------------
# {1 5,2 Silver,3 86,4 60000}
# input38 : ['S', '5', '86', '60000']
# classify : {'Gold': 6}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {3 48,4 60000}
# input39 : ['S', '0', '48', '60000']
# classify : {'Basic': 14}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 42,4 80000}
# input40 : ['M', '1', '42', '80000']
# classify : {'Gold': 4}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {3 23,4 60000}
# input41 : ['S', '0', '23', '60000']
# classify : {'Basic': 1, 'Silver': 1}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {2 Silver,3 79,4 160000}
# input42 : ['S', '0', '79', '160000']
# classify : {'Silver': 3}
# answer   : Silver
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 41,4 100000}
# input43 : ['M', '1', '41', '100000']
# classify : {'Basic': 5}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,2 Normal,3 63,4 20000}
# input44 : ['S', '1', '63', '20000']
# classify : {'Normal': 47}
# answer   : Normal
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 27,4 40000}
# input45 : ['M', '2', '27', '40000']
# classify : {'Basic': 6}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 46,4 140000}
# input46 : ['M', '1', '46', '140000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 55,4 40000}
# input47 : ['S', '0', '55', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 46,4 120000}
# input48 : ['S', '0', '46', '120000']
# classify : {'Basic': 11}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 3,3 62,4 60000}
# input49 : ['M', '3', '62', '60000']
# classify : {'Gold': 7}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,2 Silver,3 44,4 120000}
# input50 : ['S', '1', '44', '120000']
# classify : {'Basic': 55}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,2 Silver,3 55,4 80000}
# input51 : ['M', '0', '55', '80000']
# classify : {'Basic': 19}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 60,4 80000}
# input52 : ['M', '1', '60', '80000']
# classify : {'Gold': 4}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 72,4 60000}
# input53 : ['M', '1', '72', '60000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 75,4 60000}
# input54 : ['M', '1', '75', '60000']
# classify : {'Gold': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,3 75,4 60000}
# input55 : ['S', '1', '75', '60000']
# classify : {'Gold': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {1 3,2 Gold,3 37,4 40000}
# input56 : ['S', '3', '37', '40000']
# classify : {'Gold': 23}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {0 M,3 44,4 40000}
# input57 : ['M', '0', '44', '40000']
# classify : {'Basic': 21}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 80,4 40000}
# input58 : ['M', '1', '80', '40000']
# classify : {'Normal': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 68,4 100000}
# input59 : ['M', '1', '68', '100000']
# classify : {'Silver': 3}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,3 88,4 120000}
# input60 : ['S', '1', '88', '120000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 78,4 140000}
# input61 : ['S', '0', '78', '140000']
# classify : {'Basic': 7}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,2 Normal,3 65,4 40000}
# input62 : ['M', '2', '65', '40000']
# classify : {'Basic': 6}
# answer   : Normal
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 42,4 40000}
# input63 : ['M', '2', '42', '40000']
# classify : {'Basic': 6}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 59,4 120000}
# input64 : ['S', '0', '59', '120000']
# classify : {'Basic': 11}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 55,4 40000}
# input65 : ['S', '0', '55', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,3 63,4 40000}
# input66 : ['M', '0', '63', '40000']
# classify : {'Basic': 21}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 30,4 80000}
# input67 : ['M', '2', '30', '80000']
# classify : {'Basic': 2}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {2 Normal,3 73,4 60000}
# input68 : ['S', '0', '73', '60000']
# classify : {'Basic': 14}
# answer   : Normal
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,2 Silver,3 65,4 40000}
# input69 : ['S', '1', '65', '40000']
# classify : {'Basic': 1}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 24,4 40000}
# input70 : ['M', '1', '24', '40000']
# classify : {'Basic': 1}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 3,2 Gold,3 61,4 60000}
# input71 : ['S', '3', '61', '60000']
# classify : {'Gold': 4}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 4,3 62,4 40000}
# input72 : ['M', '4', '62', '40000']
# classify : {'Gold': 5}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {3 37,4 40000}
# input73 : ['S', '0', '37', '40000']
# classify : {'Normal': 2}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {1 3,2 Normal,3 29,4 100000}
# input74 : ['S', '3', '29', '100000']
# classify : {'Gold': 23}
# answer   : Normal
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,2 Silver,3 43,4 40000}
# input75 : ['M', '1', '43', '40000']
# classify : {'Silver': 1}
# answer   : Silver
# Right !!!
# -----------------------------------------------------------------------
# {0 M,2 Normal,3 55,4 40000}
# input76 : ['M', '0', '55', '40000']
# classify : {'Basic': 21}
# answer   : Normal
# Wrong !!!
# -----------------------------------------------------------------------
# {1 4,2 Gold,3 25,4 80000}
# input77 : ['S', '4', '25', '80000']
# classify : {'Gold': 2}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {0 M,3 38,4 40000}
# input78 : ['M', '0', '38', '40000']
# classify : {'Basic': 21}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 2,2 Silver,3 53,4 60000}
# input79 : ['S', '2', '53', '60000']
# classify : {'Basic': 14}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,2 Silver,3 38,4 80000}
# input80 : ['M', '1', '38', '80000']
# classify : {'Gold': 4}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {2 Silver,3 60,4 160000}
# input81 : ['S', '0', '60', '160000']
# classify : {'Silver': 3}
# answer   : Silver
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 4,2 Gold,3 36,4 100000}
# input82 : ['M', '4', '36', '100000']
# classify : {'Basic': 3}
# answer   : Gold
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 41,4 40000}
# input83 : ['M', '2', '41', '40000']
# classify : {'Basic': 6}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 52,4 140000}
# input84 : ['S', '0', '52', '140000']
# classify : {'Basic': 7}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 70,4 60000}
# input85 : ['M', '2', '70', '60000']
# classify : {'Basic': 4}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,3 79,4 60000}
# input86 : ['S', '1', '79', '60000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 72,4 20000}
# input87 : ['S', '0', '72', '20000']
# classify : {'Normal': 47}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 29,4 40000}
# input88 : ['M', '1', '29', '40000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,2 Silver,3 42,4 100000}
# input89 : ['M', '0', '42', '100000']
# classify : {'Silver': 4}
# answer   : Silver
# Right !!!
# -----------------------------------------------------------------------
# {1 1,3 72,4 140000}
# input90 : ['S', '1', '72', '140000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {2 Normal,3 54,4 20000}
# input91 : ['S', '0', '54', '20000']
# classify : {'Normal': 47}
# answer   : Normal
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 3,2 Gold,3 76,4 40000}
# input92 : ['M', '3', '76', '40000']
# classify : {'Gold': 23}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {3 72,4 40000}
# input93 : ['S', '0', '72', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 65,4 60000}
# input94 : ['M', '1', '65', '60000']
# classify : {'Silver': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 2,2 Gold,3 36,4 40000}
# input95 : ['M', '2', '36', '40000']
# classify : {'Basic': 6}
# answer   : Gold
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 59,4 60000}
# input96 : ['M', '1', '59', '60000']
# classify : {'Basic': 1}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 50,4 40000}
# input97 : ['M', '2', '50', '40000']
# classify : {'Basic': 6}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 64,4 40000}
# input98 : ['S', '0', '64', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,2 Silver,3 24,4 60000}
# input99 : ['S', '1', '24', '60000']
# classify : {'Normal': 1}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {3 74,4 60000}
# input100 : ['S', '0', '74', '60000']
# classify : {'Basic': 14}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 59,4 80000}
# input101 : ['M', '1', '59', '80000']
# classify : {'Gold': 4}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,3 24,4 40000}
# input102 : ['S', '1', '24', '40000']
# classify : {'Normal': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 56,4 40000}
# input103 : ['M', '1', '56', '40000']
# classify : {'Silver': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {3 50,4 140000}
# input104 : ['S', '0', '50', '140000']
# classify : {'Basic': 7}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 3,2 Gold,3 89,4 40000}
# input105 : ['S', '3', '89', '40000']
# classify : {'Gold': 23}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {1 1,2 Gold,3 87,4 60000}
# input106 : ['S', '1', '87', '60000']
# classify : {'Basic': 55}
# answer   : Gold
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,2 Silver,3 37,4 40000}
# input107 : ['M', '0', '37', '40000']
# classify : {'Normal': 2}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,3 71,4 60000}
# input108 : ['S', '1', '71', '60000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 35,4 20000}
# input109 : ['S', '0', '35', '20000']
# classify : {'Normal': 47}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {1 5,2 Normal,3 54,4 20000}
# input110 : ['S', '5', '54', '20000']
# classify : {'Normal': 47}
# answer   : Normal
# Right !!!
# -----------------------------------------------------------------------
# {3 63,4 40000}
# input111 : ['S', '0', '63', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 42,4 60000}
# input112 : ['S', '0', '42', '60000']
# classify : {'Silver': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 3,2 Gold,3 71,4 100000}
# input113 : ['M', '3', '71', '100000']
# classify : {'Gold': 23}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {1 1,2 Normal,3 53,4 20000}
# input114 : ['S', '1', '53', '20000']
# classify : {'Normal': 47}
# answer   : Normal
# Right !!!
# -----------------------------------------------------------------------
# {0 M,3 51,4 40000}
# input115 : ['M', '0', '51', '40000']
# classify : {'Basic': 1}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 57,4 40000}
# input116 : ['M', '1', '57', '40000']
# classify : {'Gold': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {3 80,4 40000}
# input117 : ['S', '0', '80', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,2 Gold,3 83,4 160000}
# input118 : ['M', '2', '83', '160000']
# classify : {'Normal': 1}
# answer   : Gold
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,3 83,4 120000}
# input119 : ['S', '1', '83', '120000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 45,4 40000}
# input120 : ['S', '0', '45', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,3 52,4 80000}
# input121 : ['M', '0', '52', '80000']
# classify : {'Basic': 19}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 76,4 80000}
# input122 : ['M', '2', '76', '80000']
# classify : {'Basic': 19}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,3 64,4 60000}
# input123 : ['S', '1', '64', '60000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 2,2 Gold,3 54,4 80000}
# input124 : ['S', '2', '54', '80000']
# classify : {'Basic': 19}
# answer   : Gold
# Wrong !!!
# -----------------------------------------------------------------------
# {3 56,4 60000}
# input125 : ['S', '0', '56', '60000']
# classify : {'Basic': 1}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 43,4 40000}
# input126 : ['M', '2', '43', '40000']
# classify : {'Basic': 6}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,2 Silver,3 74,4 40000}
# input127 : ['S', '1', '74', '40000']
# classify : {'Basic': 55}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 3,2 Gold,3 21,4 40000}
# input128 : ['M', '3', '21', '40000']
# classify : {'Gold': 23}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 4,2 Normal,3 88,4 120000}
# input129 : ['M', '4', '88', '120000']
# classify : {'Basic': 3}
# answer   : Normal
# Wrong !!!
# -----------------------------------------------------------------------
# {1 2,3 26,4 60000}
# input130 : ['S', '2', '26', '60000']
# classify : {'Basic': 2}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 4,2 Normal,3 62,4 20000}
# input131 : ['M', '4', '62', '20000']
# classify : {'Normal': 47}
# answer   : Normal
# Right !!!
# -----------------------------------------------------------------------
# {1 2,3 36,4 40000}
# input132 : ['S', '2', '36', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,2 Silver,3 85,4 40000}
# input133 : ['S', '1', '85', '40000']
# classify : {'Basic': 2}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 2,2 Normal,3 56,4 80000}
# input134 : ['M', '2', '56', '80000']
# classify : {'Silver': 2}
# answer   : Normal
# Wrong !!!
# -----------------------------------------------------------------------
# {2 Gold,3 24,4 100000}
# input135 : ['S', '0', '24', '100000']
# classify : {'Basic': 7}
# answer   : Gold
# Wrong !!!
# -----------------------------------------------------------------------
# {2 Silver,3 82,4 60000}
# input136 : ['S', '0', '82', '60000']
# classify : {'Basic': 14}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {3 57,4 40000}
# input137 : ['S', '0', '57', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 61,4 40000}
# input138 : ['M', '2', '61', '40000']
# classify : {'Basic': 6}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 2,3 75,4 120000}
# input139 : ['S', '2', '75', '120000']
# classify : {'Basic': 1}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 2,3 33,4 160000}
# input140 : ['S', '2', '33', '160000']
# classify : {'Silver': 3}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,2 Normal,3 73,4 40000}
# input141 : ['M', '0', '73', '40000']
# classify : {'Basic': 21}
# answer   : Normal
# Wrong !!!
# -----------------------------------------------------------------------
# {1 3,3 86,4 60000}
# input142 : ['S', '3', '86', '60000']
# classify : {'Gold': 4}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {3 31,4 40000}
# input143 : ['S', '0', '31', '40000']
# classify : {'Basic': 1}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,3 86,4 60000}
# input144 : ['S', '1', '86', '60000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,3 39,4 80000}
# input145 : ['S', '1', '39', '80000']
# classify : {'Basic': 7}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 85,4 60000}
# input146 : ['S', '0', '85', '60000']
# classify : {'Normal': 2}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {1 4,2 Normal,3 89,4 60000}
# input147 : ['S', '4', '89', '60000']
# classify : {'Gold': 2}
# answer   : Normal
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,3 31,4 40000}
# input148 : ['M', '0', '31', '40000']
# classify : {'Gold': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,2 Silver,3 48,4 60000}
# input149 : ['M', '1', '48', '60000']
# classify : {'Basic': 55}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {3 45,4 40000}
# input150 : ['S', '0', '45', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 51,4 80000}
# input151 : ['S', '0', '51', '80000']
# classify : {'Gold': 2}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,2 Normal,3 77,4 20000}
# input152 : ['M', '0', '77', '20000']
# classify : {'Normal': 47}
# answer   : Normal
# Right !!!
# -----------------------------------------------------------------------
# {0 M,3 50,4 100000}
# input153 : ['M', '0', '50', '100000']
# classify : {'Silver': 4}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {2 Gold,3 80,4 60000}
# input154 : ['S', '0', '80', '60000']
# classify : {'Basic': 14}
# answer   : Gold
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,3 62,4 100000}
# input155 : ['M', '0', '62', '100000']
# classify : {'Silver': 4}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,2 Gold,3 58,4 40000}
# input156 : ['M', '0', '58', '40000']
# classify : {'Basic': 21}
# answer   : Gold
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,2 Silver,3 54,4 80000}
# input157 : ['S', '1', '54', '80000']
# classify : {'Basic': 7}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {2 Silver,3 35,4 60000}
# input158 : ['S', '0', '35', '60000']
# classify : {'Normal': 2}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {1 2,3 88,4 40000}
# input159 : ['S', '2', '88', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 2,3 29,4 80000}
# input160 : ['S', '2', '29', '80000']
# classify : {'Normal': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,2 Silver,3 32,4 60000}
# input161 : ['S', '1', '32', '60000']
# classify : {'Basic': 55}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,2 Silver,3 34,4 20000}
# input162 : ['S', '1', '34', '20000']
# classify : {'Normal': 47}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,3 60,4 40000}
# input163 : ['M', '0', '60', '40000']
# classify : {'Basic': 21}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,2 Gold,3 27,4 160000}
# input164 : ['M', '0', '27', '160000']
# classify : {'Gold': 3}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {1 3,2 Gold,3 83,4 100000}
# input165 : ['S', '3', '83', '100000']
# classify : {'Gold': 23}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 48,4 80000}
# input166 : ['M', '1', '48', '80000']
# classify : {'Gold': 4}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 80,4 40000}
# input167 : ['M', '1', '80', '40000']
# classify : {'Normal': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 3,2 Normal,3 86,4 40000}
# input168 : ['M', '3', '86', '40000']
# classify : {'Gold': 23}
# answer   : Normal
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,3 55,4 60000}
# input169 : ['M', '0', '55', '60000']
# classify : {'Silver': 4}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 53,4 40000}
# input170 : ['M', '1', '53', '40000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 4,2 Gold,3 73,4 120000}
# input171 : ['S', '4', '73', '120000']
# classify : {'Gold': 2}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {3 25,4 60000}
# input172 : ['S', '0', '25', '60000']
# classify : {'Basic': 1}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,3 59,4 60000}
# input173 : ['S', '1', '59', '60000']
# classify : {'Basic': 1}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,3 90,4 40000}
# input174 : ['S', '1', '90', '40000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {3 29,4 40000}
# input175 : ['S', '0', '29', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 3,2 Gold,3 78,4 40000}
# input176 : ['M', '3', '78', '40000']
# classify : {'Gold': 23}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {1 2,3 37,4 40000}
# input177 : ['S', '2', '37', '40000']
# classify : {'Normal': 2}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 77,4 80000}
# input178 : ['M', '1', '77', '80000']
# classify : {'Gold': 4}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {1 2,2 Silver,3 87,4 60000}
# input179 : ['S', '2', '87', '60000']
# classify : {'Basic': 14}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,3 22,4 40000}
# input180 : ['S', '1', '22', '40000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {2 Normal,3 46,4 20000}
# input181 : ['S', '0', '46', '20000']
# classify : {'Normal': 47}
# answer   : Normal
# Right !!!
# -----------------------------------------------------------------------
# {1 2,3 49,4 60000}
# input182 : ['S', '2', '49', '60000']
# classify : {'Silver': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,3 37,4 40000}
# input183 : ['M', '0', '37', '40000']
# classify : {'Normal': 2}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,2 Silver,3 69,4 40000}
# input184 : ['M', '0', '69', '40000']
# classify : {'Basic': 21}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 5,2 Silver,3 37,4 80000}
# input185 : ['M', '5', '37', '80000']
# classify : {'Gold': 6}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,2 Silver,3 61,4 60000}
# input186 : ['M', '1', '61', '60000']
# classify : {'Gold': 1}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 49,4 80000}
# input187 : ['M', '1', '49', '80000']
# classify : {'Gold': 4}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {1 1,3 39,4 60000}
# input188 : ['S', '1', '39', '60000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 41,4 80000}
# input189 : ['M', '2', '41', '80000']
# classify : {'Basic': 19}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,2 Normal,3 28,4 60000}
# input190 : ['M', '1', '28', '60000']
# classify : {'Basic': 55}
# answer   : Normal
# Wrong !!!
# -----------------------------------------------------------------------
# {3 75,4 60000}
# input191 : ['S', '0', '75', '60000']
# classify : {'Basic': 1}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,2 Silver,3 22,4 60000}
# input192 : ['M', '0', '22', '60000']
# classify : {'Silver': 4}
# answer   : Silver
# Right !!!
# -----------------------------------------------------------------------
# {1 3,2 Gold,3 76,4 40000}
# input193 : ['S', '3', '76', '40000']
# classify : {'Gold': 23}
# answer   : Gold
# Right !!!
# -----------------------------------------------------------------------
# {1 3,2 Normal,3 26,4 20000}
# input194 : ['S', '3', '26', '20000']
# classify : {'Normal': 47}
# answer   : Normal
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 4,2 Silver,3 63,4 20000}
# input195 : ['M', '4', '63', '20000']
# classify : {'Normal': 47}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {3 36,4 80000}
# input196 : ['S', '0', '36', '80000']
# classify : {'Basic': 19}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,2 Normal,3 86,4 20000}
# input197 : ['S', '1', '86', '20000']
# classify : {'Normal': 47}
# answer   : Normal
# Right !!!
# -----------------------------------------------------------------------
# {3 57,4 60000}
# input198 : ['S', '0', '57', '60000']
# classify : {'Basic': 14}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 2,3 83,4 40000}
# input199 : ['S', '2', '83', '40000']
# classify : {'Basic': 13}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,2 Silver,3 83,4 40000}
# input200 : ['M', '1', '83', '40000']
# classify : {'Basic': 55}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,2 Silver,3 58,4 40000}
# input201 : ['M', '1', '58', '40000']
# classify : {'Basic': 1}
# answer   : Silver
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 50,4 100000}
# input202 : ['M', '1', '50', '100000']
# classify : {'Basic': 5}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,3 76,4 60000}
# input203 : ['M', '0', '76', '60000']
# classify : {'Silver': 4}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 34,4 40000}
# input204 : ['M', '2', '34', '40000']
# classify : {'Basic': 6}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 2,3 62,4 20000}
# input205 : ['M', '2', '62', '20000']
# classify : {'Normal': 47}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,3 87,4 40000}
# input206 : ['M', '0', '87', '40000']
# classify : {'Basic': 21}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 32,4 40000}
# input207 : ['M', '1', '32', '40000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {1 1,3 87,4 40000}
# input208 : ['S', '1', '87', '40000']
# classify : {'Basic': 55}
# answer   : Basic
# Right !!!
# -----------------------------------------------------------------------
# {0 M,1 1,3 39,4 80000}
# input209 : ['M', '1', '39', '80000']
# classify : {'Gold': 4}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------
# {0 M,3 85,4 40000}
# input210 : ['M', '0', '85', '40000']
# classify : {'Gold': 1}
# answer   : Basic
# Wrong !!!
# -----------------------------------------------------------------------

# %%
acc = right_count/len(question)
print("accuracy : " + str(acc))
# Out:
# accuracy : 0.5545023696682464

# %% [markdown]
# # out put to txt file

# %%
with open("output.txt", "w") as f:
    for i in output:
        if i is not output[-1]:
            f.write(i+" \n")
        else:
            f.write(i)
print("...............................OK")
# Out:
# ...............................OK
